# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread("./imgs/1.jpg")

# %%
image.shape
# Out:
# (478, 720, 3)

# %%
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
image = np.repeat(image[:, :, np.newaxis], 3, 2)

# %%
plt.figure(figsize=(15,20))
plt.imshow(image, cmap=None)
plt.axis('off')
# Out:
# (-0.5, 719.5, 477.5, -0.5)

# %%
image.shape
# Out:
# (478, 720, 3)

# %%
image
# Out:
# array([[ 43,  48,  26, ..., 106, 106, 106],
#        [ 64,  61,  44, ..., 112, 109, 107],
#        [ 63,  57,  55, ..., 119, 117, 116],
#        ...,
#        [ 13,  26,  38, ..., 121, 126, 123],
#        [ 28,  34,  41, ...,  84,  90,  92],
#        [ 30,  33,  37, ...,  35,  32,  35]], dtype=uint8)

# %%
image[:, :, np.newaxis].shape
# Out:
# (478, 720, 1)
